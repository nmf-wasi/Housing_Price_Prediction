# %% [markdown]
# ```
# └── Housing Price Prediction/
#     ├── .gitignore
#     ├── config.py
#     ├── requirements.txt
#     ├── src/
#     │   ├── data_processing.py
#     │   ├── evaluation.py
#     │   ├── feature_importance.py
#     │   ├── main.py
#     │   ├── predict.py
#     │   ├── save_model.py
#     │   └── train.py
#     ├── notebooks/
#     │   ├── 01_eda.ipynb
#     │   ├── 02_preprocessing.ipynb
#     │   └── 03_model.ipynb
#     ├── images/
#     │   ├── 1stFlrSF_distribution.png
#     │   ├── correlation_matrix.png
#     │   ├── FullBath_distribution.png
#     │   ├── GarageArea_distribution.png
#     │   ├── GarageCars_distribution.png
#     │   ├── GrLivArea_distribution.png
#     │   ├── OverallQual_distribution.png
#     │   ├── SalePrice_distribution.png
#     │   ├── TotalBsmtSF_distribution.png
#     │   ├── TotRmsAbvGrd_distribution.png
#     │   ├── YearBuilt_distribution.png
#     │   └── YearRemodAdd_distribution.png
#     └── data/
#         ├── data_description.txt
#         ├── test.csv
#         └── train.csv
# ```
